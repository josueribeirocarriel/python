# %% [markdown]
# <a href="https://colab.research.google.com/github/josueribeirocarriel/python/blob/main/PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**AULA 1** 🤕 🧟 🦟 🦂
# ![image.png](data:image/png;base64,...)

# %%
ano = "IX"
print(ano," competição de programação dá Start")
# Out:
# IX  competição de programação dá Start

# %% [markdown]
# #**AULA 2** ⏰ ♈ ⛪

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais do ana são {pontos_ana}")
print(f"Os pontos totais do ana e Rodrigo são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais do ana são 46
# Os pontos totais do ana e Rodrigo são 70

# %% [markdown]
# # **AULA** 3 ✈ 😇 🐾

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)

# %% [markdown]
# #**AULA** **4** ❎ ❌ ⏪

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 8
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80

# %% [markdown]
# # **AULA** **5** ✈ ❗ 0

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero / contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 6
# 6 x 1 = 6.0
# 6 x 2 = 3.0
# 6 x 3 = 2.0
# 6 x 4 = 1.5
# 6 x 5 = 1.2
# 6 x 6 = 1.0
# 6 x 7 = 0.8571428571428571
# 6 x 8 = 0.75
# 6 x 9 = 0.6666666666666666
# 6 x 10 = 0.6

# %% [markdown]
# # **AULA** **6** **chatbot** ⛏ ✊ ⛵

# %%
print("Olá, sou eu assistente virtual")
nome = input("digite seu nome")
print(f"Olá {nome}, em que posso ajudar?")
resposta = input("você deseja falar sobre python, javascript ou matematica:").lower()
if resposta =="python":
  print(f"Ótimo, {nome}, vamos falar sobre Python!")
elif resposta =="matemática":
   print(f"Ótimo, {nome}, vamos falar sobre matematica!")
elif resposta =="javascript":
   print(f"Ótimo, {nome}, vamos falar sobre javascript!")
# Out:
# Olá, sou eu assistente virtual
# digite seu nomel
# Olá l, em que posso ajudar?
# você deseja falar sobre python, javascript ou matematica:matematica
